# %%
import requests

# %%
search = 'hallyday'
url = 'https://commons.wikimedia.org/w/api.php?action=query&list=allimages&aiprop=url|name|title|extmetadata&aifrom=' + search + '&format=json'
response = requests.get(url)

# %%
response.json()
# Out:
# {'batchcomplete': '',
#  'continue': {'aicontinue': 'Hallé,_Jean_CIPB1839.jpg', 'continue': '-||'},
#  'query': {'allimages': [{'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=59273359',
#     'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Hallyeo_National_Marine_Park_near_Tongeong.jpg',
#     'extmetadata': {'Artist': {'source': 'commons-desc-page',
#       'value': '<a href="//commons.wikimedia.org/w/index.php?title=User:Olga_Lipunova&amp;action=edit&amp;redlink=1" class="new" title="User:Olga Lipunova (page does not exist)">Olga Lipunova</a>'},
#      'Assessments': {'hidden': '',
#       'source': 'commons-categories',
#       'value': ''},
#      'AttributionRequired': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'true'},
#      'Categories': {'hidden': '',
#       'source': 'commons-categories',
#       'value': 'Hallyeohaesang|Images from Wiki Loves Earth 2017|Images from Wiki Loves Earth 2017 in South Korea|Self-published work|Uploaded via Campaign:wle-kr'},
#      'CommonsMetadataExtension': {'hidden': '',
#       'source': 'extension',
#       'value': 1.2},
#      'Copyrighted': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'True'},
#      'Credit': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': '<span class="int-own-work" lang="en">Own work</span>'},
#      'DateTime': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': '2017-05-25 00:24:18'},
#      'DateTimeOriginal': {'source': 'commons-desc-page',
#       'value': '2010-08-07 13:48:42'},
#      'ImageDescription': {'source': 'commons-desc-page',
#       'value': 'Hallyeo National Marine Park, South Korea'},
#      'License': {'hidden': '',
#       'source': 'commons-templates',
#       'value': 'cc-by-sa-4.0'},
#      'LicenseShortName': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'CC BY-SA 4.0'},
#      'LicenseUrl': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'https://creativecommons.org/licenses/by-sa/4.0'},
#      'ObjectName': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': 'Hallyeo National Marine Park near Tongeong'},
#      'Restrictions': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': ''},
#      'UsageTerms': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Creative Commons Attribution-Share Alike 4.0'}},
#     'name': 'Hallyeo_National_Marine_Park_near_Tongeong.jpg',
#     'ns': 6,
#     'title': 'File:Hallyeo National Marine Park near Tongeong.jpg',
#     'url': 'https://upload.wikimedia.org/wikipedia/commons/e/e8/Hallyeo_National_Marine_Park_near_Tongeong.jpg'},
#    {'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=13826072',
#     'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Hallym9.JPG',
#     'extmetadata': {'Artist': {'source': 'commons-desc-page',
#       'value': 'hallym'},
#      'Assessments': {'hidden': '',
#       'source': 'commons-categories',
#       'value': ''},
#      'AttributionRequired': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'true'},
#      'Categories': {'hidden': '',
#       'source': 'commons-categories',
#       'value': 'Hallym University|Self-published work'},
#      'CommonsMetadataExtension': {'hidden': '',
#       'source': 'extension',
#       'value': 1.2},
#      'Copyrighted': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'True'},
#      'Credit': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'hallym'},
#      'DateTime': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': '2011-02-24 21:47:04'},
#      'DateTimeOriginal': {'source': 'commons-desc-page', 'value': ''},
#      'ImageDescription': {'source': 'commons-desc-page', 'value': 'hallym'},
#      'License': {'hidden': '',
#       'source': 'commons-templates',
#       'value': 'cc-by-3.0'},
#      'LicenseShortName': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'CC BY 3.0'},
#      'LicenseUrl': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'http://creativecommons.org/licenses/by/3.0'},
#      'ObjectName': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': 'Hallym9'},
#      'Restrictions': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': ''},
#      'UsageTerms': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Creative Commons Attribution 3.0'}},
#     'name': 'Hallym9.JPG',
#     'ns': 6,
#     'title': 'File:Hallym9.JPG',
#     'url': 'https://upload.wikimedia.org/wikipedia/commons/7/71/Hallym9.JPG'},
#    {'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=45949764',
#     'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Hallym_Polytechnic_University_Annex_Building.JPG',
#     'extmetadata': {'Artist': {'source': 'commons-desc-page',
#       'value': '<a href="//commons.wikimedia.org/wiki/User:Jhcbs1019" title="User:Jhcbs1019">Jhcbs1019</a>'},
#      'Assessments': {'hidden': '',
#       'source': 'commons-categories',
#       'value': ''},
#      'AttributionRequired': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'true'},
#      'Categories': {'hidden': '',
#       'source': 'commons-categories',
#       'value': 'Chuncheon|Self-published work|Universities and colleges in Gangwon-do (South Korea)'},
#      'CommonsMetadataExtension': {'hidden': '',
#       'source': 'extension',
#       'value': 1.2},
#      'Copyrighted': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'True'},
#      'Credit': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': '<span class="int-own-work" lang="en">Own work</span>'},
#      'DateTime': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': '2015-12-29 05:05:37'},
#      'DateTimeOriginal': {'source': 'commons-desc-page',
#       'value': '2015-07-30 15:48:46'},
#      'ImageDescription': {'source': 'commons-desc-page',
#       'value': 'Hallym Polytechnic University Annex Building'},
#      'License': {'hidden': '',
#       'source': 'commons-templates',
#       'value': 'cc-by-sa-4.0'},
#      'LicenseShortName': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'CC BY-SA 4.0'},
#      'LicenseUrl': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'https://creativecommons.org/licenses/by-sa/4.0'},
#      'ObjectName': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': 'Hallym Polytechnic University Annex Building'},
#      'Restrictions': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': ''},
#      'UsageTerms': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Creative Commons Attribution-Share Alike 4.0'}},
#     'name': 'Hallym_Polytechnic_University_Annex_Building.JPG',
#     'ns': 6,
#     'title': 'File:Hallym Polytechnic University Annex Building.JPG',
#     'url': 'https://upload.wikimedia.org/wikipedia/commons/b/b4/Hallym_Polytechnic_University_Annex_Building.JPG'},
#    {'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=45949763',
#     'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Hallym_Polytechnic_University_Main_Building.JPG',
#     'extmetadata': {'Artist': {'source': 'commons-desc-page',
#       'value': '<a href="//commons.wikimedia.org/wiki/User:Jhcbs1019" title="User:Jhcbs1019">Jhcbs1019</a>'},
#      'Assessments': {'hidden': '',
#       'source': 'commons-categories',
#       'value': ''},
#      'AttributionRequired': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'true'},
#      'Categories': {'hidden': '',
#       'source': 'commons-categories',
#       'value': 'Chuncheon|Self-published work|Universities and colleges in Gangwon-do (South Korea)'},
#      'CommonsMetadataExtension': {'hidden': '',
#       'source': 'extension',
#       'value': 1.2},
#      'Copyrighted': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'True'},
#      'Credit': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': '<span class="int-own-work" lang="en">Own work</span>'},
#      'DateTime': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': '2015-12-29 05:05:36'},
#      'DateTimeOriginal': {'source': 'commons-desc-page',
#       'value': '2015-07-30 15:48:40'},
#      'ImageDescription': {'source': 'commons-desc-page',
#       'value': 'Hallym Polytechnic University Main Building'},
#      'License': {'hidden': '',
#       'source': 'commons-templates',
#       'value': 'cc-by-sa-4.0'},
#      'LicenseShortName': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'CC BY-SA 4.0'},
#      'LicenseUrl': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'https://creativecommons.org/licenses/by-sa/4.0'},
#      'ObjectName': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': 'Hallym Polytechnic University Main Building'},
#      'Restrictions': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': ''},
#      'UsageTerms': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Creative Commons Attribution-Share Alike 4.0'}},
#     'name': 'Hallym_Polytechnic_University_Main_Building.JPG',
#     'ns': 6,
#     'title': 'File:Hallym Polytechnic University Main Building.JPG',
#     'url': 'https://upload.wikimedia.org/wikipedia/commons/8/83/Hallym_Polytechnic_University_Main_Building.JPG'},
#    {'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=45949721',
#     'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Hallym_Polytechnic_University_Main_gate.JPG',
#     'extmetadata': {'Artist': {'source': 'commons-desc-page',
#       'value': '<a href="//commons.wikimedia.org/wiki/User:Jhcbs1019" title="User:Jhcbs1019">Jhcbs1019</a>'},
#      'Assessments': {'hidden': '',
#       'source': 'commons-categories',
#       'value': ''},
#      'AttributionRequired': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'true'},
#      'Categories': {'hidden': '',
#       'source': 'commons-categories',
#       'value': 'Chuncheon|Self-published work|Universities and colleges in Gangwon-do (South Korea)'},
#      'CommonsMetadataExtension': {'hidden': '',
#       'source': 'extension',
#       'value': 1.2},
#      'Copyrighted': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'True'},
#      'Credit': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': '<span class="int-own-work" lang="en">Own work</span>'},
#      'DateTime': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': '2015-12-29 05:00:04'},
#      'DateTimeOriginal': {'source': 'commons-desc-page',
#       'value': '2015-07-30 15:40:57'},
#      'ImageDescription': {'source': 'commons-desc-page',
#       'value': 'Main gate of Hallym Polytechnic University'},
#      'License': {'hidden': '',
#       'source': 'commons-templates',
#       'value': 'cc-by-sa-4.0'},
#      'LicenseShortName': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'CC BY-SA 4.0'},
#      'LicenseUrl': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'https://creativecommons.org/licenses/by-sa/4.0'},
#      'ObjectName': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': 'Hallym Polytechnic University Main gate'},
#      'Restrictions': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': ''},
#      'UsageTerms': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Creative Commons Attribution-Share Alike 4.0'}},
#     'name': 'Hallym_Polytechnic_University_Main_gate.JPG',
#     'ns': 6,
#     'title': 'File:Hallym Polytechnic University Main gate.JPG',
#     'url': 'https://upload.wikimedia.org/wikipedia/commons/8/81/Hallym_Polytechnic_University_Main_gate.JPG'},
#    {'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=13074807',
#     'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Hallywell_Hill_-_geograph.org.uk_-_544999.jpg',
#     'extmetadata': {'Artist': {'source': 'commons-desc-page',
#       'value': '<a rel="nofollow" class="external text" href="http://www.geograph.org.uk/profile/196">Richard Webb</a>'},
#      'Assessments': {'hidden': '',
#       'source': 'commons-categories',
#       'value': ''},
#      'Attribution': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Richard Webb'},
#      'AttributionRequired': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'true'},
#      'Categories': {'hidden': '',
#       'source': 'commons-categories',
#       'value': 'Ashkirk|Farms in the Scottish Borders|Geograph images in the Scottish Borders|Images by Richard Webb|Images from Geograph Britain and Ireland|Images from Geograph needing category review as of 2 August 2011|Media with locations|Pages with maps'},
#      'CommonsMetadataExtension': {'hidden': '',
#       'source': 'extension',
#       'value': 1.2},
#      'Copyrighted': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'True'},
#      'Credit': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'From <a rel="nofollow" class="external text" href="http://www.geograph.org.uk/photo/544999">geograph.org.uk</a>'},
#      'DateTime': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': '2011-02-05 23:37:40'},
#      'DateTimeOriginal': {'source': 'commons-desc-page',
#       'value': '2007-09-03'},
#      'GPSLatitude': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': '55.463099'},
#      'GPSLongitude': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': '-2.775701'},
#      'GPSMapDatum': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'WGS-84'},
#      'ImageDescription': {'source': 'commons-desc-page',
#       'value': 'Hallywell Hill The grass in the foreground was not mown, due to the soft ground being unable to take ordinary tractor tyres without ruts and compaction. Drier ground was cut and baled as hay.'},
#      'License': {'hidden': '',
#       'source': 'commons-templates',
#       'value': 'cc-by-sa-2.0'},
#      'LicenseShortName': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'CC BY-SA 2.0'},
#      'LicenseUrl': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'https://creativecommons.org/licenses/by-sa/2.0'},
#      'ObjectName': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': 'Hallywell Hill - geograph.org.uk - 544999'},
#      'Restrictions': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': ''},
#      'UsageTerms': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Creative Commons Attribution-Share Alike 2.0'}},
#     'name': 'Hallywell_Hill_-_geograph.org.uk_-_544999.jpg',
#     'ns': 6,
#     'title': 'File:Hallywell Hill - geograph.org.uk - 544999.jpg',
#     'url': 'https://upload.wikimedia.org/wikipedia/commons/8/8f/Hallywell_Hill_-_geograph.org.uk_-_544999.jpg'},
#    {'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=13768900',
#     'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Hallywell_Rig_-_geograph.org.uk_-_1060533.jpg',
#     'extmetadata': {'Artist': {'source': 'commons-desc-page',
#       'value': '<a rel="nofollow" class="external text" href="http://www.geograph.org.uk/profile/196">Richard Webb</a>'},
#      'Assessments': {'hidden': '',
#       'source': 'commons-categories',
#       'value': ''},
#      'Attribution': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Richard Webb'},
#      'AttributionRequired': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'true'},
#      'Categories': {'hidden': '',
#       'source': 'commons-categories',
#       'value': 'Geograph images in the Scottish Borders|Images by Richard Webb|Images from Geograph Britain and Ireland|Longformacus|Media needing category review as of 22 July 2017|Media with locations|Pages with maps'},
#      'CommonsMetadataExtension': {'hidden': '',
#       'source': 'extension',
#       'value': 1.2},
#      'Copyrighted': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'True'},
#      'Credit': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'From <a rel="nofollow" class="external text" href="http://www.geograph.org.uk/photo/1060533">geograph.org.uk</a>'},
#      'DateTime': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': '2011-02-24 04:13:05'},
#      'DateTimeOriginal': {'source': 'commons-desc-page',
#       'value': '2008-11-26'},
#      'GPSLatitude': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': '55.777520'},
#      'GPSLongitude': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': '-2.471221'},
#      'GPSMapDatum': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'WGS-84'},
#      'ImageDescription': {'source': 'commons-desc-page',
#       'value': 'Hallywell Rig Moorland ridge with Dirrington Little Law in the distance.'},
#      'License': {'hidden': '',
#       'source': 'commons-templates',
#       'value': 'cc-by-sa-2.0'},
#      'LicenseShortName': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'CC BY-SA 2.0'},
#      'LicenseUrl': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'https://creativecommons.org/licenses/by-sa/2.0'},
#      'ObjectName': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': 'Hallywell Rig - geograph.org.uk - 1060533'},
#      'Restrictions': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': ''},
#      'UsageTerms': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Creative Commons Attribution-Share Alike 2.0'}},
#     'name': 'Hallywell_Rig_-_geograph.org.uk_-_1060533.jpg',
#     'ns': 6,
#     'title': 'File:Hallywell Rig - geograph.org.uk - 1060533.jpg',
#     'url': 'https://upload.wikimedia.org/wikipedia/commons/8/8f/Hallywell_Rig_-_geograph.org.uk_-_1060533.jpg'},
#    {'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=932938',
#     'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Hall%C3%A4ndsk_bonde_1715,_Nordisk_familjebok.png',
#     'extmetadata': {'Artist': {'source': 'commons-desc-page',
#       'value': 'Nordisk familjebok'},
#      'Assessments': {'hidden': '',
#       'source': 'commons-categories',
#       'value': ''},
#      'AttributionRequired': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'false'},
#      'Categories': {'hidden': '',
#       'source': 'commons-categories',
#       'value': 'Anonymous-EU|Halland|Images from Nordisk familjebok'},
#      'CommonsMetadataExtension': {'hidden': '',
#       'source': 'extension',
#       'value': 1.2},
#      'Copyrighted': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'False'},
#      'Credit': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': '<a href="//commons.wikimedia.org/wiki/Nordisk_familjebok" title="Nordisk familjebok">Nordisk familjebok</a> (1908), vol.8, p.749 <a rel="nofollow" class="external autonumber" href="http://runeberg.org/nfbh/0411.html">[1]</a>'},
#      'DateTime': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': '2006-07-08 23:14:56'},
#      'DateTimeOriginal': {'source': 'commons-desc-page', 'value': '1908'},
#      'ImageDescription': {'source': 'commons-desc-page',
#       'value': 'Farmer from Halland in Sweden, 1715'},
#      'License': {'hidden': '', 'source': 'commons-templates', 'value': 'pd'},
#      'LicenseShortName': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Public domain'},
#      'ObjectName': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': 'Halländsk bonde 1715, Nordisk familjebok'},
#      'Permission': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': '<table class="licensetpl" style="display:none"><tr><td>\n<span class="licensetpl_short">Public domain</span><span class="licensetpl_long">Public domain</span><span class="licensetpl_link_req">false</span><span class="licensetpl_attr_req">false</span>\n</td></tr></table>\n<table style="width:100%; clear:both; margin:0.5em auto; background-color:#f7f8ff; border:2px solid #8888aa; direction: ltr; border-spacing: 8px; padding: 0px;" class="layouttemplate mw-content-ltr" lang="en"><tr>\n<td> <a href="//commons.wikimedia.org/wiki/File:PD-icon.svg" class="image" title="Public domain"><img alt="Public domain" src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/PD-icon.svg/64px-PD-icon.svg.png" width="64" height="64" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/PD-icon.svg/96px-PD-icon.svg.png 1.5x, https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/PD-icon.svg/128px-PD-icon.svg.png 2x" data-file-width="196" data-file-height="196"></a>\n</td>\n<td> <span lang="en" class="description en"><i>This image was first published in the 1st (1876–1899), 2nd (1904–1926) or 3rd (1923–1937) edition of</i> <a href="https://en.wikipedia.org/wiki/Nordisk_familjebok" class="extiw" title="en:Nordisk familjebok">Nordisk familjebok</a><i>. The <a href="https://en.wikipedia.org/wiki/Copyrights" class="extiw" title="w:Copyrights">copyrights</a> for that book have expired and this image is in the public domain, because images had no named authors and the book was published more than 70 years ago.</i></span>\n</td>\n<td> <div class="floatright"><img alt="Logo för Nordisk familjeboks uggleupplaga.png" src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e9/Logo_f%C3%B6r_Nordisk_familjeboks_uggleupplaga.png/50px-Logo_f%C3%B6r_Nordisk_familjeboks_uggleupplaga.png" width="50" height="59" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e9/Logo_f%C3%B6r_Nordisk_familjeboks_uggleupplaga.png/75px-Logo_f%C3%B6r_Nordisk_familjeboks_uggleupplaga.png 1.5x, https://upload.wikimedia.org/wikipedia/commons/thumb/e/e9/Logo_f%C3%B6r_Nordisk_familjeboks_uggleupplaga.png/100px-Logo_f%C3%B6r_Nordisk_familjeboks_uggleupplaga.png 2x" data-file-width="605" data-file-height="716"></div>\n</td>\n</tr></table>\n<table class="licensetpl" style="display:none"><tr><td>\n<span class="licensetpl_short">Public domain</span><span class="licensetpl_long">Public domain</span><span class="licensetpl_link_req">false</span><span class="licensetpl_attr_req">false</span>\n</td></tr></table>\n<table style="width:100%; clear:both; margin:0.5em auto; background-color:#f7f8ff; border:2px solid #8888aa; direction: ltr; border-spacing: 8px; padding: 0px;" class="layouttemplate mw-content-ltr" lang="en">\n<tr>\n<td> <img alt="Public domain" src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/PD-icon.svg/64px-PD-icon.svg.png" title="Public domain" width="64" height="64" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/PD-icon.svg/96px-PD-icon.svg.png 1.5x, https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/PD-icon.svg/128px-PD-icon.svg.png 2x" data-file-width="196" data-file-height="196">\n</td>\n<td> <span lang="en" class="description en"><i>This image (or other media file) is in the <b><a href="https://en.wikipedia.org/wiki/public_domain" class="extiw" title="w:public domain">public domain</a></b> because its copyright has <b>expired</b> and its author is <b>anonymous</b>.</i><br><p><i>This applies to the <a href="//commons.wikimedia.org/wiki/European_Union" title="European Union">European Union</a> and those countries with a copyright term of 70 years after the work was made available to the public and the author never disclosed their identity.</i><br><i><b>Important</b>: Always mention where the image comes from, as far as possible, and make sure the author never claimed authorship.</i></p></span>\n\n</td>\n<td> <div class="floatright"><img alt="Flag of Europe" src="https://upload.wikimedia.or ...
#      'Restrictions': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': ''},
#      'UsageTerms': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Public domain'}},
#     'name': 'Halländsk_bonde_1715,_Nordisk_familjebok.png',
#     'ns': 6,
#     'title': 'File:Halländsk bonde 1715, Nordisk familjebok.png',
#     'url': 'https://upload.wikimedia.org/wikipedia/commons/b/be/Hall%C3%A4ndsk_bonde_1715%2C_Nordisk_familjebok.png'},
#    {'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=1376511',
#     'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Hall%C3%A9%27s_Justice_of_Trajan.jpg',
#     'extmetadata': {'Artist': {'source': 'commons-desc-page',
#       'value': '<bdi><a href="https://en.wikipedia.org/wiki/en:No%C3%ABl_Hall%C3%A9" class="extiw" title="w:en:Noël Hallé">Noël Hallé</a>\n</bdi>'},
#      'Assessments': {'hidden': '',
#       'source': 'commons-categories',
#       'value': ''},
#      'AttributionRequired': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'false'},
#      'Categories': {'hidden': '',
#       'source': 'commons-categories',
#       'value': '1765 paintings|Artworks without Wikidata item|CC-PD-Mark|Justice in art|Mothers in art|Noël Hallé|PD-Art (PD-old-100)|Traianus'},
#      'CommonsMetadataExtension': {'hidden': '',
#       'source': 'extension',
#       'value': 1.2},
#      'Copyrighted': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'False'},
#      'Credit': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Utpictura18\xa0: <a rel="nofollow" class="external autonumber" href="https://utpictura18.univ-amu.fr/GenerateurNotice.php?numnotice=A0362">[1]</a>'},
#      'DateTime': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': '2006-11-16 23:19:37'},
#      'DateTimeOriginal': {'source': 'commons-desc-page', 'value': '1765'},
#      'ImageDescription': {'source': 'commons-desc-page',
#       'value': '<div class="description">\n<i>The Justice of <a href="//commons.wikimedia.org/wiki/Trajan" class="mw-redirect" title="Trajan">Trajan</a></i>. 265x302 cm</div>'},
#      'License': {'hidden': '', 'source': 'commons-templates', 'value': 'pd'},
#      'LicenseShortName': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Public domain'},
#      'ObjectName': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': "Hallé's Justice of Trajan"},
#      'Permission': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': '<table cellspacing="8" cellpadding="0" style="clear:both; margin:0.5em auto; background-color:#f0f0f0; border:2px solid #e0e0e0; direction: ltr;" class="layouttemplate"><tr><td>\n<center>This is a faithful photographic reproduction of a two-dimensional, <a href="//commons.wikimedia.org/wiki/Public_domain" class="mw-redirect" title="Public domain">public domain</a> work of art. The work of art itself is in the public domain for the following reason:\n<table class="licensetpl" style="display:none"><tr><td>\n<span class="licensetpl_short">Public domain</span><span class="licensetpl_long">Public domain</span><span class="licensetpl_link_req">false</span><span class="licensetpl_attr_req">false</span>\n</td></tr></table>\n<table style="width:100%; clear:both; margin:0.5em auto; background-color:#f7f8ff; border:2px solid #8888aa; direction: ltr; border-spacing: 8px; padding: 0px;" class="layouttemplate mw-content-ltr" lang="en">\n<tr>\n<td rowspan="2"> <img alt="Public domain" src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/PD-icon.svg/64px-PD-icon.svg.png" title="Public domain" width="64" height="64" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/PD-icon.svg/96px-PD-icon.svg.png 1.5x, https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/PD-icon.svg/128px-PD-icon.svg.png 2x" data-file-width="196" data-file-height="196">\n</td>\n<td>\n<p>This work is in the <b><a href="https://en.wikipedia.org/wiki/public_domain" class="extiw" title="en:public domain">public domain</a></b> in its country of origin and other countries and areas where the <a href="https://en.wikipedia.org/wiki/List_of_countries%27_copyright_length" class="extiw" title="w:List of countries\' copyright length">copyright term</a> is the author\'s <b>life plus 100 years or less</b>.\n</p>\n<hr>\n<p><img alt="Dialog-warning.svg" src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/Dialog-warning.svg/25px-Dialog-warning.svg.png" width="25" height="25" srcset="https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/Dialog-warning.svg/38px-Dialog-warning.svg.png 1.5x, https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/Dialog-warning.svg/50px-Dialog-warning.svg.png 2x" data-file-width="48" data-file-height="48"><small>You must also include a <a href="//commons.wikimedia.org/wiki/Commons:Copyright_tags#United_States" title="Commons:Copyright tags">United States public domain tag</a> to indicate why this work is in the public domain in the United States.</small>\n</p>\n</td>\n</tr>\n<tr><td colspan="2">\n<center><span style="font-size:x-small;line-height:140%" class="plainlinks"><a rel="nofollow" class="external text" href="https://creativecommons.org/publicdomain/mark/1.0/deed.en">This file has been identified as being free of known restrictions under copyright law, including all related and neighboring rights.</a></span></center>\n</td></tr>\n</table>\nThe official position taken by the Wikimedia Foundation is that "<i>faithful reproductions of two-dimensional public domain works of art are public domain</i>".<br><b>This photographic reproduction is therefore also considered to be in the public domain in the United States.</b> In other jurisdictions, re-use of this content may be restricted; <b>see <a href="//commons.wikimedia.org/wiki/Commons:Reuse_of_PD-Art_photographs" title="Commons:Reuse of PD-Art photographs">Reuse of PD-Art photographs</a> for details.</b>\n</center>  \n</td></tr></table>'},
#      'Restrictions': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': ''},
#      'UsageTerms': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Public domain'}},
#     'name': "Hallé's_Justice_of_Trajan.jpg",
#     'ns': 6,
#     'title': "File:Hallé's Justice of Trajan.jpg",
#     'url': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Hall%C3%A9%27s_Justice_of_Trajan.jpg'},
#    {'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=11142680',
#     'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Hall%C3%A9,_Jean-No%C3%ABl,_d%27apr%C3%A8s_Gounod.jpg',
#     'extmetadata': {'Artist': {'source': 'commons-desc-page',
#       'value': "J.M.N. Frémy (graveur), d'après François-Louis Gounod (peintre)."},
#      'Assessments': {'hidden': '',
#       'source': 'commons-categories',
#       'value': ''},
#      'AttributionRequired': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'false'},
#      'Categories': {'hidden': '',
#       'source': 'commons-categories',
#       'value': 'CC-PD-Mark|Jacques Marie Noël Frémy|Jean Noël Hallé|PD-Art (PD-old)|PD-Art (PD-old default)|PD Old'},
#      'CommonsMetadataExtension': {'hidden': '',
#       'source': 'extension',
#       'value': 1.2},
#      'Copyrighted': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'False'},
#      'Credit': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': "J.M.N. Frémy, <i>Croquis des portraits des personnages remarquables dans tous les genres, dessinés et gravés par J.M.N. Frémy, d'après les tableaux exposés aux différens salons</i>, t. I, Paris, 1815."},
#      'DateTime': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': '2010-08-10 17:18:17'},
#      'DateTimeOriginal': {'source': 'commons-desc-page', 'value': '1815'},
#      'ImageDescription': {'source': 'commons-desc-page',
#       'value': '<p>Jean Noël Hallé.\n</p>'},
#      'License': {'hidden': '', 'source': 'commons-templates', 'value': 'pd'},
#      'LicenseShortName': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Public domain'},
#      'ObjectName': {'hidden': '',
#       'source': 'mediawiki-metadata',
#       'value': "Hallé, Jean-Noël, d'après Gounod"},
#      'Restrictions': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': ''},
#      'UsageTerms': {'hidden': '',
#       'source': 'commons-desc-page',
#       'value': 'Public domain'}},
#     'name': "Hallé,_Jean-Noël,_d'après_Gounod.jpg",
#     'ns': 6,
#     'title': "File:Hallé, Jean-Noël, d'après Gounod.jpg",
#     'url': 'https://upload.wikimedia.org/wikipedia/commons/0/0f/Hall%C3%A9%2C_Jean-No%C3%ABl%2C_d%27apr%C3%A8s_Gounod.jpg'}]},
#  'warnings': {'allimages': {'*': 'Unrecognized values for parameter "aiprop": name, title.'}}}
